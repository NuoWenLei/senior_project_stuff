# %%
queries = []

filenames_1 = [
             "New_Approach_1.py",
             "new_train_sequence_1.py",
             "new_base_learner.py",
             "new_help_functions.py",
]



filenames_2 = [
               "New_Algorithmic_Approach.py",
               "New_Prediction_Pipeline.py"
]

filenames_3 = [
              "Similar_Word_Scraper.py",
              "Embed_Generator.py"
]

for fn in filenames_1:
  queries.append(f"https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/{fn}")

for fn in filenames_2:
  queries.append(f"https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Algorithmic_Approach/{fn}")

for fn in filenames_3:
  queries.append(f"https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/word_generation/{fn}")

# %%
queries
# Out:
# ['https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/New_Approach_1.py',
#  'https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/new_train_sequence_1.py',
#  'https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/new_base_learner.py',
#  'https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/new_help_functions.py',
#  'https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Algorithmic_Approach/New_Algorithmic_Approach.py',
#  'https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Algorithmic_Approach/New_Prediction_Pipeline.py',
#  'https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/word_generation/Similar_Word_Scraper.py',
#  'https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/word_generation/Embed_Generator.py']

# %%
import subprocess
# Download and import my module files from GitHub
result = subprocess.run(["wget", "--no-cache", "--backups=1"] + queries, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
print(result.stderr.decode("utf-8"))
# Out:
# --2022-05-04 16:33:25--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/New_Approach_1.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3796 (3.7K) [text/plain]
# Failed to rename New_Approach_1.py to New_Approach_1.py.1: (2) No such file or directory
# Saving to: ‘New_Approach_1.py’
#
#      0K ...                                                   100% 23.1M=0s
#
# 2022-05-04 16:33:25 (23.1 MB/s) - ‘New_Approach_1.py’ saved [3796/3796]
#
# --2022-05-04 16:33:25--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/new_train_sequence_1.py
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7152 (7.0K) [text/plain]
# Failed to rename new_train_sequence_1.py to new_train_sequence_1.py.1: (2) No such file or directory
# Saving to: ‘new_train_sequence_1.py’
#
#      0K ......                                                100% 18.8M=0s
#
# 2022-05-04 16:33:25 (18.8 MB/s) - ‘new_train_sequence_1.py’ saved [7152/7152]
#
# --2022-05-04 16:33:25--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/new_base_learner.py
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 469 [text/plain]
# Failed to rename new_base_learner.py to new_base_learner.py.1: (2) No such file or directory
# Saving to: ‘new_base_learner.py’
#
#      0K                                                       100% 25.9M=0s
#
# 2022-05-04 16:33:25 (25.9 MB/s) - ‘new_base_learner.py’ saved [469/469]
#
# --2022-05-04 16:33:25--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Part_A/new_help_functions.py
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3805 (3.7K) [text/plain]
# Failed to rename new_help_functions.py to new_help_functions.py.1: (2) No such file or directory
# Saving to: ‘new_help_functions.py’
#
#      0K ...                                                   100% 38.6M=0s
#
# 2022-05-04 16:33:25 (38.6 MB/s) - ‘new_help_functions.py’ saved [3805/3805]
#
# --2022-05-04 16:33:25--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Algorithmic_Approach/New_Algorithmic_Approach.py
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1051 (1.0K) [text/plain]
# Failed to rename New_Algorithmic_Approach.py to New_Algorithmic_Approach.py.1: (2) No such file or directory
# Saving to: ‘New_Algorithmic_Approach.py’
#
#      0K .                                                     100% 51.8M=0s
#
# 2022-05-04 16:33:25 (51.8 MB/s) - ‘New_Algorithmic_Approach.py’ saved [1051/1051]
#
# --2022-05-04 16:33:25--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/Algorithmic_Approach/New_Prediction_Pipeline.py
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5197 (5.1K) [text/plain]
# Failed to rename New_Prediction_Pipeline.py to New_Prediction_Pipeline.py.1: (2) No such file or directory
# Saving to: ‘New_Prediction_Pipeline.py’
#
#      0K .....                                                 100% 53.6M=0s
#
# 2022-05-04 16:33:25 (53.6 MB/s) - ‘New_Prediction_Pipeline.py’ saved [5197/5197]
#
# --2022-05-04 16:33:25--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/word_generation/Similar_Word_Scraper.py
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2054 (2.0K) [text/plain]
# Failed to rename Similar_Word_Scraper.py to Similar_Word_Scraper.py.1: (2) No such file or directory
# Saving to: ‘Similar_Word_Scraper.py’
#
#      0K ..                                                    100% 29.7M=0s
#
# 2022-05-04 16:33:25 (29.7 MB/s) - ‘Similar_Word_Scraper.py’ saved [2054/2054]
#
# --2022-05-04 16:33:25--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/word_generation/Embed_Generator.py
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 319 [text/plain]
# Failed to rename Embed_Generator.py to Embed_Generator.py.1: (2) No such file or directory
# Saving to: ‘Embed_Generator.py’
#
#      0K                                                       100% 17.1M=0s
#
# 2022-05-04 16:33:26 (17.1 MB/s) - ‘Embed_Generator.py’ saved [319/319]
#
# FINISHED --2022-05-04 16:33:26--
# Total wall clock time: 0.9s
# Downloaded: 8 files, 23K in 0.001s (27.5 MB/s)

# %%
# !wget --no-cache --backups=1 https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/housing_params.json
# Out:
# --2022-05-04 16:33:26--  https://raw.githubusercontent.com/NuoWenLei/senior_project_stuff/main/housing_params.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 900 [text/plain]
# Failed to rename housing_params.json to housing_params.json.1: (2) No such file or directory
# Saving to: ‘housing_params.json’
#
# housing_params.json 100%[===================>]     900  --.-KB/s    in 0s
#
# 2022-05-04 16:33:26 (24.3 MB/s) - ‘housing_params.json’ saved [900/900]

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import json

with open("housing_params.json", "r") as salary_params_json:
  params = json.load(salary_params_json)

# %%
params
# Out:
# {'BASE_LAYERS': 0,
#  'BASE_NEURONS': 64,
#  'BATCH_SIZE': 1,
#  'DATA_CYCLES': 20,
#  'DATA_PATH': '/content/gdrive/MyDrive/Senior_Project_Stuff/dataset_specific_tries/housing_prediction/house_clean.csv',
#  'D_FF': 512,
#  'D_MODEL': 300,
#  'EMBED_PATH': '/content/gdrive/MyDrive/Senior_Project_Stuff/dataset_specific_tries/housing_prediction/house_embedding_matrix.npy',
#  'EPOCHS': 600,
#  'EPOCH_SAVE_LIST': [99, 199, 299, 399, 499, 599],
#  'FEATURE_SIZE': 11,
#  'HEADS': 10,
#  'HIDDEN_SIZE': 512,
#  'LEARNER_EPOCHS': 1,
#  'LEARNER_STEPS': 16,
#  'META_EPOCHS': 16,
#  'META_STEPS': 16,
#  'MODEL_SAVE_PATH': 'TODO',
#  'NUM_CLASSES': 1,
#  'NUM_SIMILAR_WORDS': 5,
#  'QUERY_SIZE': 30,
#  'SEQUENCE_LENGTH': 1,
#  'STARTING_EPOCH': 0,
#  'STARTING_VOCAB': 'housing',
#  'VERBOSE': 1,
#  'VOCAB_DEPTH': 4,
#  'VOCAB_PATH': '/content/gdrive/MyDrive/Senior_Project_Stuff/dataset_specific_tries/housing_prediction/house_centered_words.json'}

# %%
from Embed_Generator import *
from Similar_Word_Scraper import *

# %%
import pandas as pd

data = pd.read_csv(params["DATA_PATH"])

# %%
data.head()
# Out:
#    per capita crime rate by town  \
# 0                        1.23247
# 1                        0.02177
# 2                        4.89822
# 3                        0.03961
# 4                        3.69311
#
#    proportion of non retail business acres per town  \
# 0                                              8.14
# 1                                              2.03
# 2                                             18.10
# 3                                              5.19
# 4                                             18.10
#
#    nitric oxides concentration  rooms per dwelling  \
# 0                        0.538               6.142
# 1                        0.415               7.610
# 2                        0.631               4.970
# 3                        0.515               6.037
# 4                        0.713               6.376
#
#    proportion of owner occupied units built  \
# 0                                      91.7
# 1                                      15.7
# 2                                     100.0
# 3                                      34.5
# 4                                      88.4
#
#    distances to five Boston employment centres  \
# 0                                       3.9769
# 1                                       6.2700
# 2                                       1.3325
# 3                                       5.9853
# 4                                       2.5671
#
#    accessibility to radial highways  \
# 0                               4.0
# 1                               2.0
# 2                              24.0
# 3                               5.0
# 4                              24.0
#
#    full value property tax rate per thousand of dollars  \
# 0                                              307.0
# 1                                              348.0
# 2                                              666.0
# 3                                              224.0
# 4                                              666.0
#
#    pupil to teacher ratio by town  proportion of blacks by town  \
# 0                            21.0                        396.90
# 1                            14.7                        395.38
# 2                            20.2                        375.52
# 3                            20.2                        396.90
# 4                            20.2                        391.43
#
#    lower status of the population  \
# 0                           18.72
# 1                            3.11
# 2                            3.26
# 3                            8.01
# 4                           14.65
#
#    value of owner occupied homes in thousand of dollars
# 0                                               15.2
# 1                                               42.3
# 2                                               50.0
# 3                                               21.1
# 4                                               17.7

# %%
feature_words = []

for i in data.columns:
  feature_words.extend(i.lower().split(" "))

# %%
feature_words_set = list(set(feature_words))

# %%
feature_words_set
# Out:
# ['proportion',
#  'five',
#  'accessibility',
#  'dollars',
#  'homes',
#  'pupil',
#  'occupied',
#  'blacks',
#  'non',
#  'to',
#  'dwelling',
#  'in',
#  'of',
#  'rate',
#  'owner',
#  'crime',
#  'boston',
#  'highways',
#  'acres',
#  'thousand',
#  'per',
#  'ratio',
#  'centres',
#  'teacher',
#  'units',
#  'value',
#  'concentration',
#  'retail',
#  'nitric',
#  'radial',
#  'full',
#  'distances',
#  'lower',
#  'status',
#  'tax',
#  'property',
#  'town',
#  'population',
#  'the',
#  'rooms',
#  'business',
#  'oxides',
#  'capita',
#  'built',
#  'by',
#  'employment']

# %%
Similar_Word_Scraper.initialize_nltk()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
word_scraper = Similar_Word_Scraper(feature_words_set, params["VOCAB_DEPTH"])

# %%
word_set = word_scraper()
# Out:
# 0
# 100%|██████████| 46/46 [00:01<00:00, 24.97it/s]
# Length of new queue: 496
# 1
# 100%|██████████| 496/496 [00:03<00:00, 142.01it/s]
# Length of new queue: 3550
# 2
# 100%|██████████| 3550/3550 [00:35<00:00, 99.95it/s]
# Length of new queue: 5788
# 3
# 100%|██████████| 5788/5788 [01:43<00:00, 55.74it/s]
# Length of new queue: 3890

# %%
with open(params["VOCAB_PATH"], "w") as vocab_json:
  json.dump(word_set, vocab_json)

# %%
# !python3 -m spacy download en_core_web_md
# Out:
# Collecting en_core_web_md==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.2.5/en_core_web_md-2.2.5.tar.gz (96.4 MB)
#      |████████████████████████████████| 96.4 MB 1.1 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_md==2.2.5) (2.2.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (7.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.21.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.7)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (4.64.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (0.9.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (3.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (1.24.3)
# Building wheels for collected packages: en-core-web-md
#   Building wheel for en-core-web-md (setup.py) ... done
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.2.5-py3-none-any.whl size=98051301 sha256=58b8a260e2d212a4b8a987604b7bc01e31e5d7fa9b0b8ac3f74c5f1d71f79f2a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nrzhbrb3/wheels/69/c5/b8/4f1c029d89238734311b3269762ab2ee325a42da2ce8edb997
# Successfully built en-core-web-md
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %% [markdown]
# ## Restart Runtime here

# %%
import json
with open("housing_params.json", "r") as params_json:
  params = json.load(params_json)

# %%
with open(params["VOCAB_PATH"], "r") as vocab_json:
  vocab = json.load(vocab_json)

# %%
with open(params["VOCAB_PATH"], "w") as vocab_json_write:
  json.dump([i[0] for i in vocab], vocab_json_write)

# %%
from Embed_Generator import *

# %%
embed_generator = Embed_Generator([i[0] for i in vocab])

# %%
np_embeds = embed_generator()
# Out:
# 100%|██████████| 9880/9880 [01:08<00:00, 144.62it/s]

# %%
np_embeds.shape
# Out:
# (9880, 300)

# %%
import numpy as np
with open(params["EMBED_PATH"], "wb") as f:
  np.save(f, np_embeds)

# %% [markdown]
# # Train Sequence

# %%
from new_train_sequence_1 import *

# %%
part_a_interpreter, algo, logs = train_sequence("housing_params.json", dataset_name = "salary")
# Out:
# On Epoch 0
# Epoch 0, Step 0: 0.267, Most Similar Words: ['amount' 'increase' 'less' 'higher' 'lower'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5814139  0.62839484 0.58687663 0.5543333  0.4951076 ]
#
#
# Epoch 0, Step 1: 0.720, Most Similar Words: ['canasta' 'rummy' 'klondike' 'bodoni' 'saul'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [-0.0634368  -0.0634368  -0.0634368  -0.15982434 -0.11935881]
#
#
# Epoch 0, Step 2: 0.455, Most Similar Words: ['dressed' 'belongs' 'preside' 'tribe' 'appoint'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.04683231 0.17748646 0.02153037 0.09288348 0.02153037]
#
#
# Epoch 0, Step 3: 0.715, Most Similar Words: ['slotted' 'stylus' 'protrudes' 'angled' 'prongs'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [ 0.10267742 -0.02650124  0.10267742  0.10267742  0.10267742]
#
#
# Epoch 0, Step 4: 0.440, Most Similar Words: ['functional' 'fragile' 'platforms' 'distinctive' 'outer'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.44555473 0.26178858 0.3111525  0.38944885 0.3285095 ]
#
#
# Epoch 0, Step 5: 0.621, Most Similar Words: ['nanna' 'homework' 'breath' 'laughter' 'merriment'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.16111918 0.2916833  0.26843807 0.2070411  0.2070411 ]
#
#
# Epoch 0, Step 6: 0.558, Most Similar Words: ['month' 'apartment' 'rent' 'home' 'fee'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.17146492 0.2829364  0.27009106 0.29162288 0.28224522]
#
#
# Epoch 0, Step 7: 0.904, Most Similar Words: ['mournfulness' 'jutes' 'plantigrade' 'carpels' 'weightlift'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [-0.21473977 -0.24855031 -0.20283774 -0.04148908 -0.27039126]
#
#
# Epoch 0, Step 8: 0.283, Most Similar Words: ['minimum' 'higher' 'maximum' 'increase' 'depending'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.40753555 0.4915871  0.34545872 0.4631949  0.42291266]
#
#
# Epoch 0, Step 9: 0.379, Most Similar Words: ['full' 'access' 'open' 'separate' 'offering'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.4406028  0.35114056 0.31409422 0.41057268 0.36421594]
#
#
# Epoch 0, Step 10: 0.369, Most Similar Words: ['extent' 'significant' 'greater' 'particular' 'way'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.6347951  0.679933   0.67118233 0.63598675 0.552506  ]
#
#
# Epoch 0, Step 11: 0.458, Most Similar Words: ['promontory' 'owners' 'unobstructed' 'built' 'tenants'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.3056658  0.5765353  0.3056658  0.4784892  0.49218255]
#
#
# Epoch 0, Step 12: 0.322, Most Similar Words: ['property' 'houses' 'pay' 'house' 'private'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.43102467 0.39580342 0.56512356 0.4140022  0.42376354]
#
#
# Epoch 0, Step 13: 0.648, Most Similar Words: ['preside' 'guest' 'studio' 'appoint' 'loft'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.31188172 0.3275248  0.31905437 0.31188172 0.35804567]
#
#
# Epoch 0, Step 14: 0.518, Most Similar Words: ['classes' 'class' 'master' 'parent' 'teaching'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.2393902  0.23494579 0.13078997 0.20434727 0.18207827]
#
#
# Epoch 0, Step 15: 0.571, Most Similar Words: ['proclaim' 'throne' 'predecessor' 'successors' 'nobleman'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.07747874 0.15811378 0.00314633 0.00314633 0.09985449]
#
#
# Epoch 0 Average MAE: 0.5142874121665955
# On Epoch 1
# Epoch 1, Step 0: 0.715, Most Similar Words: ['modifier' 'modifiers' 'compatibility' 'graphite' 'instants'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [ 0.0882048   0.0882048   0.18464108  0.15723279 -0.01999602]
#
#
# Epoch 1, Step 1: 0.498, Most Similar Words: ['intermediate' 'therapeutic' 'heighten' 'stress' 'optimal'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.3726472  0.28040808 0.39997134 0.38838547 0.3666701 ]
#
#
# Epoch 1, Step 2: 0.312, Most Similar Words: ['houses' 'house' 'town' 'living' 'people'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.362167   0.27114674 0.3944169  0.35306245 0.44263944]
#
#
# Epoch 1, Step 3: 0.374, Most Similar Words: ['requisite' 'associated' 'i.e.' 'furnish' 'sufficient'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5453061 0.4463875 0.5472078 0.5453061 0.5453061]
#
#
# Epoch 1, Step 4: 0.282, Most Similar Words: ['amount' 'proportion' 'reduced' 'increase' 'less'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.46256763 0.4237821  0.39967853 0.4631949  0.47804335]
#
#
# Epoch 1, Step 5: 0.521, Most Similar Words: ['compatibility' 'capabilities' 'integrated' 'platforms' 'logistics'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.08254962 0.20622686 0.20053315 0.15325856 0.17666468]
#
#
# Epoch 1, Step 6: 0.421, Most Similar Words: ['functional' 'resilient' 'flexible' 'pliable' 'conformable'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.41701475 0.2513192  0.2513192  0.2513192  0.2513192 ]
#
#
# Epoch 1, Step 7: 0.426, Most Similar Words: ['develop' 'management' 'key' 'valuable' 'field'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.3692521  0.3936326  0.39737648 0.5054943  0.41541898]
#
#
# Epoch 1, Step 8: 0.223, Most Similar Words: ['greater' 'certain' 'one' 'significant' 'amount'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5165517  0.43572804 0.5091632  0.4958859  0.5814139 ]
#
#
# Epoch 1, Step 9: 0.358, Most Similar Words: ['certain' 'present' 'i.e.' 'different' 'necessary'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.54740554 0.4994302  0.53469235 0.5284625  0.4787344 ]
#
#
# Epoch 1, Step 10: 0.413, Most Similar Words: ['occupied' 'vacant' 'unoccupied' 'dwelling' 'abode'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.27796695 0.27796695 0.27796695 0.21912532 0.21912532]
#
#
# Epoch 1, Step 11: 0.273, Most Similar Words: ['building' 'valuable' 'properties' 'units' 'space'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.47689927 0.26521364 0.3467421  0.5360217  0.49706486]
#
#
# Epoch 1, Step 12: 0.296, Most Similar Words: ['dollars' 'cost' 'hundred' 'land' 'parcel'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.43010896 0.48901692 0.53733194 0.58612925 0.58612925]
#
#
# Epoch 1, Step 13: 0.290, Most Similar Words: ['land' 'parcel' 'tax' 'ownership' 'full'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.47501582 0.47501582 0.41276446 0.40615243 0.43860593]
#
#
# Epoch 1, Step 14: 0.335, Most Similar Words: ['certain' 'many' 'the' 'of' 'different'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.48479384 0.45556596 0.47482315 0.40897065 0.4674088 ]
#
#
# Epoch 1, Step 15: 0.500, Most Similar Words: ['intermediate' 'suitable' 'facilitate' 'functional' 'secondary'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.27668092 0.3210801  0.33216086 0.27149233 0.34359396]
#
#
# Epoch 1 Average MAE: 0.38967084884643555
# On Epoch 2
# Epoch 2, Step 0: 0.297, Most Similar Words: ['costs' 'revenue' 'limit' 'rates' 'fees'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.3813518  0.34295148 0.38446116 0.37880966 0.38010535]
#
#
# Epoch 2, Step 1: 0.203, Most Similar Words: ['the' 'of' 'one' 'certain' 'even'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.6096978  0.65781575 0.5943598  0.5767186  0.5795255 ]
#
#
# Epoch 2, Step 2: 0.308, Most Similar Words: ['city' 'town' 'owners' 'people' 'the'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5062459  0.4393947  0.3794241  0.5916456  0.74065113]
#
#
# Epoch 2, Step 3: 0.261, Most Similar Words: ['place' 'town' 'area' 'places' 'city'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.60331815 0.54322684 0.54315567 0.58550453 0.5679271 ]
#
#
# Epoch 2, Step 4: 0.238, Most Similar Words: ['persons' 'average' 'cost' 'basis' 'income'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.4898226  0.6365781  0.56999713 0.55582774 0.61256427]
#
#
# Epoch 2, Step 5: 0.418, Most Similar Words: ['concentration' 'levels' 'ratio' 'oxygen' 'respiration'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.36061642 0.4531711  0.37833983 0.24405937 0.24405937]
#
#
# Epoch 2, Step 6: 0.446, Most Similar Words: ['depending' 'areas' 'minimum' 'area' 'increase'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.37191772 0.3459892  0.35632628 0.26867753 0.48299962]
#
#
# Epoch 2, Step 7: 0.429, Most Similar Words: ['extension' 'configuration' 'platforms' 'platform' 'extends'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.20881513 0.21532704 0.1550486  0.14202625 0.20073563]
#
#
# Epoch 2, Step 8: 0.250, Most Similar Words: ['supplementary' 'additional' 'access' 'parcel' 'land'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5032497  0.5032497  0.41555214 0.58612925 0.58612925]
#
#
# Epoch 2, Step 9: 0.359, Most Similar Words: ['narrow' 'upper' 'uppermost' 'passage' 'regions'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.4534738  0.36874112 0.36874112 0.3380033  0.41057265]
#
#
# Epoch 2, Step 10: 0.218, Most Similar Words: ['population' 'middle' 'high' 'way' 'point'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.34499276 0.4678946  0.4123497  0.56728536 0.46399024]
#
#
# Epoch 2, Step 11: 0.348, Most Similar Words: ['critical' 'primary' 'specific' 'important' 'potential'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.40235198 0.42556134 0.47134167 0.46131867 0.5236424 ]
#
#
# Epoch 2, Step 12: 0.269, Most Similar Words: ['greater' 'significant' 'lower' 'increase' 'i.e.'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.45149878 0.4500702  0.4415679  0.4631949  0.4542577 ]
#
#
# Epoch 2, Step 13: 0.328, Most Similar Words: ['total' 'units' 'persons' 'of' 'houses'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.45678103 0.32871354 0.5358828  0.65781575 0.48276848]
#
#
# Epoch 2, Step 14: 0.301, Most Similar Words: ['homes' 'houses' 'buildings' 'persons' 'dwellings'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.39405254 0.4092817  0.39233875 0.5233383  0.407156  ]
#
#
# Epoch 2, Step 15: 0.370, Most Similar Words: ['dwellings' 'vacant' 'dwelling' 'abode' 'occupied'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5095739 0.6165713 0.5095739 0.5095739 0.6165713]
#
#
# Epoch 2 Average MAE: 0.3152434229850769
# On Epoch 3
# Epoch 3, Step 0: 0.218, Most Similar Words: ['less' 'one' 'greater' 'amount' 'least'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.58687663 0.5091632  0.5165517  0.5814139  0.5296793 ]
#
#
# Epoch 3, Step 1: 0.217, Most Similar Words: ['amount' 'least' 'less' 'one' 'proportion'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.61261314 0.52880716 0.61605316 0.5886422  0.57299984]
#
#
# Epoch 3, Step 2: 0.328, Most Similar Words: ['people' 'one' 'less' 'area' 'proportion'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.23912275 0.28818065 0.40942967 0.26867753 0.4680199 ]
#
#
# Epoch 3, Step 3: 0.247, Most Similar Words: ['reduced' 'increase' 'greater' 'proportion' 'significant'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.38393882 0.41786522 0.38412678 0.41193762 0.33176318]
#
#
# Epoch 3, Step 4: 0.328, Most Similar Words: ['total' 'quantity' 'units' 'amounts' 'excess'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5063973  0.4408632  0.69019276 0.4770711  0.42868742]
#
#
# Epoch 3, Step 5: 0.386, Most Similar Words: ['rooms' 'acres' 'lease' 'spaces' 'properties'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.40078738 0.27524132 0.38231516 0.4346915  0.34788927]
#
#
# Epoch 3, Step 6: 0.313, Most Similar Words: ['income' 'country' 'first-rate' 'average' 'pay'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.2927144  0.40918884 0.3245582  0.3246712  0.34686625]
#
#
# Epoch 3, Step 7: 0.458, Most Similar Words: ['road' 'direction' 'centres' 'southwest' 'south'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.368275   0.33205855 0.27905387 0.3166715  0.3166715 ]
#
#
# Epoch 3, Step 8: 0.188, Most Similar Words: ['one' 'area' 'places' 'way' 'many'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.60319966 0.46810213 0.49162176 0.60765857 0.4786109 ]
#
#
# Epoch 3, Step 9: 0.224, Most Similar Words: ['one' 'least' 'even' 'way' 'to'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.5943598  0.56941307 0.5795255  0.5699117  0.49648622]
#
#
# Epoch 3, Step 10: 0.237, Most Similar Words: ['greater' 'least' 'one' 'significant' 'particular'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.67118233 0.5900106  0.6220069  0.679933   0.63598675]
#
#
# Epoch 3, Step 11: 0.216, Most Similar Words: ['amount' 'increase' 'proportion' 'higher' 'reduced'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.63293505 0.52366626 0.47505918 0.51620317 0.49180984]
#
#
# Epoch 3, Step 12: 0.295, Most Similar Words: ['proportion' 'fraction' 'fractional' 'increases' 'reduced'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5415996  0.41214398 0.41214398 0.5396801  0.5515163 ]
#
#
# Epoch 3, Step 13: 0.309, Most Similar Words: ['units' 'sufficient' 'structure' 'furnish' 'requisite'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.49310118 0.49325708 0.41305187 0.49325708 0.49325708]
#
#
# Epoch 3, Step 14: 0.385, Most Similar Words: ['one' 'of' 'amount' 'people' 'less'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.28818065 0.3115543  0.4940431  0.23912275 0.40942967]
#
#
# Epoch 3, Step 15: 0.207, Most Similar Words: ['of' 'the' 'one' 'less' 'people'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.37657344 0.33182177 0.4426564  0.48286465 0.46063635]
#
#
# Epoch 3 Average MAE: 0.28480881452560425
# On Epoch 4
# Epoch 4, Step 0: 0.319, Most Similar Words: ['large' 'recess' 'areas' 'portion' 'majority'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.58491147 0.46492139 0.5401362  0.46492139 0.60554993]
#
#
# Epoch 4, Step 1: 0.211, Most Similar Words: ['areas' 'area' 'places' 'town' 'city'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.54682446 0.5619183  0.6024829  0.5197872  0.594037  ]
#
#
# Epoch 4, Step 2: 0.201, Most Similar Words: ['precinct' 'towns' 'city' 'town' 'district'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.322074   0.4460967  0.46247697 0.3944169  0.322074  ]
#
#
# Epoch 4, Step 3: 0.205, Most Similar Words: ['to' 'least' 'way' 'places' 'possible'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.52738774 0.5662895  0.51698637 0.4519659  0.5518701 ]
#
#
# Epoch 4, Step 4: 0.146, Most Similar Words: ['less' 'increase' 'amount' 'greater' 'least'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.47804335 0.4631949  0.46256763 0.45149878 0.5450245 ]
#
#
# Epoch 4, Step 5: 0.113, Most Similar Words: ['increase' 'amount' 'less' 'least' 'one'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.5022885  0.55669963 0.56628305 0.56941307 0.5943598 ]
#
#
# Epoch 4, Step 6: 0.173, Most Similar Words: ['cost' 'one' 'pay' 'first-rate' 'less'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.4872599  0.6220069  0.46278977 0.5926638  0.5900512 ]
#
#
# Epoch 4, Step 7: 0.116, Most Similar Words: ['less' 'amount' 'one' 'higher' 'increase'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.6030519  0.63293505 0.6672129  0.51620317 0.52366626]
#
#
# Epoch 4, Step 8: 0.172, Most Similar Words: ['of' 'one' 'the' 'people' 'less'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.45560277 0.5091632  0.4337117  0.5099656  0.58687663]
#
#
# Epoch 4, Step 9: 0.129, Most Similar Words: ['less' 'of' 'amount' 'one' 'increase'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.61605316 0.6027084  0.61261314 0.5886422  0.59535706]
#
#
# Epoch 4, Step 10: 0.466, Most Similar Words: ['amount' 'proportion' 'of' 'half' 'one'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.4940431  0.4680199  0.3115543  0.23377758 0.28818065]
#
#
# Epoch 4, Step 11: 0.171, Most Similar Words: ['less' 'amount' 'increase' 'of' 'one'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.48286465 0.45800853 0.41786522 0.37657344 0.4426564 ]
#
#
# Epoch 4, Step 12: 0.324, Most Similar Words: ['per' 'residential' 'units' 'facilities' 'supplementary'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.37434256 0.560142   0.69019276 0.50876206 0.5032497 ]
#
#
# Epoch 4, Step 13: 0.202, Most Similar Words: ['increase' 'lower' 'less' 'higher' 'area'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.49201587 0.4574588  0.51494133 0.4898722  0.5619183 ]
#
#
# Epoch 4, Step 14: 0.192, Most Similar Words: ['population' 'higher' 'increase' 'first-rate' 'less'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.34499276 0.4322556  0.45998266 0.3245582  0.4885694 ]
#
#
# Epoch 4, Step 15: 0.294, Most Similar Words: ['the' 'population' 'middle' 'fact' 'point'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5401163  0.49318105 0.39823034 0.5183248  0.5211819 ]
#
#
# Epoch 4 Average MAE: 0.21461308002471924
# On Epoch 5
# Epoch 5, Step 0: 0.186, Most Similar Words: ['greater' 'the' 'one' 'less' 'people'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.45149878 0.5304913  0.60319966 0.47804335 0.5305285 ]
#
#
# Epoch 5, Step 1: 0.158, Most Similar Words: ['greater' 'less' 'increase' 'amount' 'higher'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.5528827  0.56628305 0.5022885  0.55669963 0.5042468 ]
#
#
# Epoch 5, Step 2: 0.106, Most Similar Words: ['less' 'least' 'one' 'individual' 'greater'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5900512  0.5900106  0.6220069  0.58802587 0.67118233]
#
#
# Epoch 5, Step 3: 0.166, Most Similar Words: ['lower' 'increase' 'less' 'higher' 'significant'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.49483883 0.52366626 0.6030519  0.51620317 0.5675325 ]
#
#
# Epoch 5, Step 4: 0.205, Most Similar Words: ['one' 'of' 'the' 'area' 'people'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5091632  0.45560277 0.4337117  0.46456409 0.5099656 ]
#
#
# Epoch 5, Step 5: 0.113, Most Similar Words: ['one' 'of' 'the' 'people' 'amount'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.5886422  0.6027084  0.52063155 0.5807807  0.61261314]
#
#
# Epoch 5, Step 6: 0.385, Most Similar Words: ['home' 'estate' 'company' 'ownership' 'five'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.1472932  0.10546124 0.15182565 0.14989413 0.2606013 ]
#
#
# Epoch 5, Step 7: 0.239, Most Similar Words: ['of' 'one' 'less' 'amount' 'people'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.37657344 0.4426564  0.48286465 0.45800853 0.46063635]
#
#
# Epoch 5, Step 8: 0.179, Most Similar Words: ['amount' 'greater' 'less' 'increase' 'significant'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5804376  0.5454364  0.55829084 0.5102483  0.5839019 ]
#
#
# Epoch 5, Step 9: 0.233, Most Similar Words: ['greater' 'area' 'areas' 'i.e.' 'certain'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.55019    0.5619183  0.54682446 0.4813345  0.5012624 ]
#
#
# Epoch 5, Step 10: 0.210, Most Similar Words: ['area' 'majority' 'areas' 'living' 'large'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.5640645  0.39580297 0.6121604  0.35306245 0.46742198]
#
#
# Epoch 5, Step 11: 0.242, Most Similar Words: ['areas' 'area' 'possible' 'places' 'individual'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.4085564  0.43942335 0.5518701  0.4519659  0.5848294 ]
#
#
# Epoch 5, Step 12: 0.270, Most Similar Words: ['town' 'cities' 'north-central' 'places' 'city'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.5654223  0.38439488 0.45550704 0.49162176 0.54364246]
#
#
# Epoch 5, Step 13: 0.206, Most Similar Words: ['the' 'city' 'country' 'past' 'town'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.6096978  0.57774943 0.5826667  0.51978606 0.60532784]
#
#
# Epoch 5, Step 14: 0.102, Most Similar Words: ['one' 'amount' 'less' 'of' 'people'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.6220069 0.5889616 0.5900512 0.7064992 0.5916456]
#
#
# Epoch 5, Step 15: 0.123, Most Similar Words: ['amount' 'increase' 'less' 'significant' 'higher'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.63293505 0.52366626 0.6030519  0.5675325  0.51620317]
#
#
# Epoch 5 Average MAE: 0.19511446356773376
# On Epoch 6
# Epoch 6, Step 0: 0.190, Most Similar Words: ['amount' 'i.e.' 'less' 'certain' 'least'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5814139  0.46287042 0.58687663 0.43572804 0.5296793 ]
#
#
# Epoch 6, Step 1: 0.249, Most Similar Words: ['hence' 'i.e.' 'proportion' 'least' 'reduced'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.49825767 0.53469235 0.57299984 0.52880716 0.52764124]
#
#
# Epoch 6, Step 2: 0.418, Most Similar Words: ['amount' 'pay' 'half' 'income' 'first-rate'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.4940431  0.14456873 0.23377758 0.21008919 0.29159153]
#
#
# Epoch 6, Step 3: 0.257, Most Similar Words: ['less' 'proportion' 'increase' 'amount' 'significant'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.48286465 0.41193762 0.41786522 0.45800853 0.33176318]
#
#
# Epoch 6, Step 4: 0.186, Most Similar Words: ['increase' 'greater' 'less' 'amount' 'significant'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5102483  0.5454364  0.55829084 0.5804376  0.5839019 ]
#
#
# Epoch 6, Step 5: 0.263, Most Similar Words: ['amount' 'greater' 'less' 'increase' 'significant'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.45847318 0.55019    0.51494133 0.49201587 0.5322585 ]
#
#
# Epoch 6, Step 6: 0.261, Most Similar Words: ['amount' 'greater' 'increase' 'less' 'significant'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.4099828  0.5049025  0.45998266 0.4885694  0.49526381]
#
#
# Epoch 6, Step 7: 0.214, Most Similar Words: ['furnish' 'greater' 'requisite' 'sufficient' 'significant'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5453061  0.5927786  0.5453061  0.5453061  0.57999015]
#
#
# Epoch 6, Step 8: 0.218, Most Similar Words: ['amount' 'requisite' 'sufficient' 'greater' 'furnish'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.46256763 0.41315168 0.41315168 0.45149878 0.41315168]
#
#
# Epoch 6, Step 9: 0.231, Most Similar Words: ['requisite' 'furnish' 'sufficient' 'amount' 'greater'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.44634607 0.44634607 0.44634607 0.55669963 0.5528827 ]
#
#
# Epoch 6, Step 10: 0.264, Most Similar Words: ['less' 'greater' 'increase' 'amount' 'significant'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5900512  0.67118233 0.64292383 0.5889616  0.679933  ]
#
#
# Epoch 6, Step 11: 0.203, Most Similar Words: ['amount' 'increase' 'less' 'greater' 'significant'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.63293505 0.52366626 0.6030519  0.5728054  0.5675325 ]
#
#
# Epoch 6, Step 12: 0.206, Most Similar Words: ['higher' 'increase' 'greater' 'significant' 'lower'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5543333  0.62839484 0.5165517  0.4958859  0.4951076 ]
#
#
# Epoch 6, Step 13: 0.161, Most Similar Words: ['less' 'increase' 'amount' 'greater' 'higher'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.61605316 0.59535706 0.61261314 0.5566164  0.553463  ]
#
#
# Epoch 6, Step 14: 0.319, Most Similar Words: ['less' 'amount' 'increase' 'cost' 'supplementary'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.40942967 0.4940431  0.48299962 0.23948693 0.32300958]
#
#
# Epoch 6, Step 15: 0.224, Most Similar Words: ['rent' 'dollars' 'selling' 'estate' 'dollar'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.50068355 0.41467547 0.2573756  0.3328363  0.3348763 ]
#
#
# Epoch 6 Average MAE: 0.24150724709033966
# On Epoch 7
# Epoch 7, Step 0: 0.270, Most Similar Words: ['homes' 'per' 'houses' 'apartment' 'house'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5651892  0.37434256 0.636371   0.5091792  0.5826457 ]
#
#
# Epoch 7, Step 1: 0.177, Most Similar Words: ['one' 'amount' 'people' 'less' 'area'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.57652646 0.45847318 0.51539326 0.51494133 0.5619183 ]
#
#
# Epoch 7, Step 2: 0.246, Most Similar Words: ['proportion' 'less' 'one' 'amount' 'greater'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.35132357 0.4885694  0.47060627 0.4099828  0.5049025 ]
#
#
# Epoch 7, Step 3: 0.250, Most Similar Words: ['one' 'greater' 'certain' 'significant' 'proportion'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.58991003 0.5927786  0.5635437  0.57999015 0.5480192 ]
#
#
# Epoch 7, Step 4: 0.202, Most Similar Words: ['greater' 'significant' 'amount' 'proportion' 'less'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.45149878 0.4500702  0.46256763 0.4237821  0.47804335]
#
#
# Epoch 7, Step 5: 0.158, Most Similar Words: ['increase' 'higher' 'amount' 'less' 'greater'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.5022885  0.5042468  0.55669963 0.56628305 0.5528827 ]
#
#
# Epoch 7, Step 6: 0.163, Most Similar Words: ['way' 'one' 'least' 'even' 'less'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.552506  0.6220069 0.5900106 0.5893697 0.5900512]
#
#
# Epoch 7, Step 7: 0.259, Most Similar Words: ['city' 'pay' 'town' 'two-way' 'way'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5679271  0.5869879  0.54322684 0.6025201  0.5689038 ]
#
#
# Epoch 7, Step 8: 0.207, Most Similar Words: ['one' 'people' 'two-way' 'way' 'city'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5091632  0.5099656  0.45346984 0.4586338  0.5310968 ]
#
#
# Epoch 7, Step 9: 0.179, Most Similar Words: ['least' 'less' 'one' 'amount' 'people'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.52880716 0.61605316 0.5886422  0.61261314 0.5807807 ]
#
#
# Epoch 7, Step 10: 0.451, Most Similar Words: ['one' 'less' 'people' 'amount' 'of'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.28818065 0.40942967 0.23912275 0.4940431  0.3115543 ]
#
#
# Epoch 7, Step 11: 0.307, Most Similar Words: ['increase' 'amount' 'extent' 'proportion' 'significant'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.41786522 0.45800853 0.31887603 0.41193762 0.33176318]
#
#
# Epoch 7, Step 12: 0.252, Most Similar Words: ['increase' 'higher' 'proportion' 'population' 'amount'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5102483  0.5127548  0.5747702  0.51861864 0.5804376 ]
#
#
# Epoch 7, Step 13: 0.241, Most Similar Words: ['one' 'population' 'proportion' 'people' 'of'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.57652646 0.45760125 0.46276894 0.51539326 0.45215103]
#
#
# Epoch 7, Step 14: 0.233, Most Similar Words: ['people' 'of' 'one' 'the' 'less'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.44263944 0.40897065 0.47060627 0.47482315 0.4885694 ]
#
#
# Epoch 7, Step 15: 0.146, Most Similar Words: ['one' 'people' 'of' 'less' 'even'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.58991003 0.5536449  0.605316   0.6537447  0.5544752 ]
#
#
# Epoch 7 Average MAE: 0.23388400673866272
# On Epoch 8
# Epoch 8, Step 0: 0.120, Most Similar Words: ['one' 'people' 'half' 'five' 'of'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.60319966 0.5305285  0.49251604 0.45228326 0.47858822]
#
#
# Epoch 8, Step 1: 0.189, Most Similar Words: ['one' 'two-way' 'to' 'way' 'pay'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.5943598  0.5604975  0.49648622 0.5699117  0.4752839 ]
#
#
# Epoch 8, Step 2: 0.202, Most Similar Words: ['two-way' 'to' 'way' 'even' 'one'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5271722 0.548347  0.552506  0.5893697 0.6220069]
#
#
# Epoch 8, Step 3: 0.224, Most Similar Words: ['to' 'way' 'possible' 'two-way' 'one'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.55193025 0.5689038  0.5419441  0.6025201  0.6672129 ]
#
#
# Epoch 8, Step 4: 0.148, Most Similar Words: ['to' 'one' 'way' 'less' 'even'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.43846887 0.5091632  0.4586338  0.58687663 0.49138376]
#
#
# Epoch 8, Step 5: 0.127, Most Similar Words: ['one' 'less' 'greater' 'least' 'even'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.5886422  0.61605316 0.5566164  0.52880716 0.53329813]
#
#
# Epoch 8, Step 6: 0.346, Most Similar Words: ['increase' 'amount' 'greater' 'one' 'less'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.48299962 0.4940431  0.47509477 0.28818065 0.40942967]
#
#
# Epoch 8, Step 7: 0.132, Most Similar Words: ['proportion' 'population' 'significant' 'less' 'greater'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.41193762 0.38375115 0.33176318 0.48286465 0.38412678]
#
#
# Epoch 8, Step 8: 0.237, Most Similar Words: ['population' 'inhabitants' 'inhabitant' 'percent' 'percentage'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.51861864 0.52157974 0.52157974 0.48642346 0.48994106]
#
#
# Epoch 8, Step 9: 0.193, Most Similar Words: ['population' 'proportion' 'persons' 'living' 'majority'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.45760125 0.46276894 0.47215086 0.4575902  0.44748992]
#
#
# Epoch 8, Step 10: 0.212, Most Similar Words: ['majority' 'of' 'proportion' 'living' 'persons'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.39580297 0.40897065 0.35132357 0.35306245 0.40721807]
#
#
# Epoch 8, Step 11: 0.165, Most Similar Words: ['less' 'people' 'amount' 'one' 'of'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.6537447  0.5536449  0.7412358  0.58991003 0.605316  ]
#
#
# Epoch 8, Step 12: 0.212, Most Similar Words: ['pay' 'less' 'cost' 'one' 'costs'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.5179006  0.47804335 0.40210187 0.60319966 0.3813518 ]
#
#
# Epoch 8, Step 13: 0.199, Most Similar Words: ['one' 'two-way' 'people' 'less' 'pay'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.5943598  0.5604975  0.6586736  0.56628305 0.4752839 ]
#
#
# Epoch 8, Step 14: 0.171, Most Similar Words: ['one' 'less' 'even' 'to' 'amount'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.6220069 0.5900512 0.5893697 0.548347  0.5889616]
#
#
# Epoch 8, Step 15: 0.173, Most Similar Words: ['greater' 'least' 'significant' 'one' 'the'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5728054 0.5809719 0.5675325 0.6672129 0.6391839]
#
#
# Epoch 8 Average MAE: 0.19069373607635498
# On Epoch 9
# Epoch 9, Step 0: 0.172, Most Similar Words: ['the' 'one' 'of' 'even' 'least'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.4337117  0.5091632  0.45560277 0.49138376 0.5296793 ]
#
#
# Epoch 9, Step 1: 0.162, Most Similar Words: ['the' 'even' 'of' 'one' 'least'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.52063155 0.53329813 0.6027084  0.5886422  0.52880716]
#
#
# Epoch 9, Step 2: 0.324, Most Similar Words: ['the' 'time' 'first-rate' 'one' 'of'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.26552042 0.2590621  0.29159153 0.28818065 0.3115543 ]
#
#
# Epoch 9, Step 3: 0.224, Most Similar Words: ['one' 'the' 'particular' 'even' 'way'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.4426564  0.33182177 0.37057304 0.39034328 0.31417173]
#
#
# Epoch 9, Step 4: 0.220, Most Similar Words: ['sufficient' 'areas' 'furnish' 'requisite' 'area'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5328545 0.5401362 0.5328545 0.5328545 0.5724242]
#
#
# Epoch 9, Step 5: 0.162, Most Similar Words: ['persons' 'average' 'per' 'less' 'depending'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.47215086 0.46236074 0.3715941  0.51494133 0.48040184]
#
#
# Epoch 9, Step 6: 0.231, Most Similar Words: ['cost' 'pay' 'costs' 'half' 'persons'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.37728813 0.34686625 0.35497126 0.3330487  0.40721807]
#
#
# Epoch 9, Step 7: 0.143, Most Similar Words: ['people' 'half' 'five' 'houses' 'one'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5536449  0.5660383  0.5505442  0.45772913 0.58991003]
#
#
# Epoch 9, Step 8: 0.168, Most Similar Words: ['one' 'of' 'less' 'people' 'amount'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.60319966 0.47858822 0.47804335 0.5305285  0.46256763]
#
#
# Epoch 9, Step 9: 0.160, Most Similar Words: ['amount' 'one' 'less' 'individual' 'certain'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.55669963 0.5943598  0.56628305 0.48410496 0.5767186 ]
#
#
# Epoch 9, Step 10: 0.172, Most Similar Words: ['least' 'area' 'one' 'less' 'individual'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5900106  0.56035924 0.6220069  0.5900512  0.58802587]
#
#
# Epoch 9, Step 11: 0.172, Most Similar Words: ['one' 'increase' 'interest' 'less' 'higher'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.6672129  0.52366626 0.60960066 0.6030519  0.51620317]
#
#
# Epoch 9, Step 12: 0.175, Most Similar Words: ['of' 'one' 'interest' 'people' 'the'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.45560277 0.5091632  0.50633866 0.5099656  0.4337117 ]
#
#
# Epoch 9, Step 13: 0.141, Most Similar Words: ['of' 'one' 'amount' 'the' 'less'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.6027084  0.5886422  0.61261314 0.52063155 0.61605316]
#
#
# Epoch 9, Step 14: 0.336, Most Similar Words: ['of' 'amount' 'less' 'one' 'greater'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.3115543  0.4940431  0.40942967 0.28818065 0.47509477]
#
#
# Epoch 9, Step 15: 0.208, Most Similar Words: ['amount' 'of' 'less' 'one' 'greater'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.45800853 0.37657344 0.48286465 0.4426564  0.38412678]
#
#
# Epoch 9 Average MAE: 0.19815291464328766
# On Epoch 10
# Epoch 10, Step 0: 0.164, Most Similar Words: ['less' 'certain' 'of' 'amount' 'greater'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.55829084 0.5739165  0.6333932  0.5804376  0.5454364 ]
#
#
# Epoch 10, Step 1: 0.179, Most Similar Words: ['persons' 'living' 'less' 'large' 'proportion'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.47215086 0.4575902  0.51494133 0.5015606  0.46276894]
#
#
# Epoch 10, Step 2: 0.162, Most Similar Words: ['persons' 'living' 'inhabitants' 'inhabitant' 'places'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.40721807 0.35306245 0.28720966 0.28720966 0.5604757 ]
#
#
# Epoch 10, Step 3: 0.205, Most Similar Words: ['persons' 'half' 'average' 'living' 'five'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.519521   0.5660383  0.61452806 0.46860448 0.5505442 ]
#
#
# Epoch 10, Step 4: 0.138, Most Similar Words: ['living' 'houses' 'residence' 'persons' 'residences'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.47084004 0.37228253 0.40927252 0.38022217 0.40927252]
#
#
# Epoch 10, Step 5: 0.130, Most Similar Words: ['one' 'area' 'individual' 'place' 'least'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.5943598  0.51691216 0.48410496 0.530418   0.56941307]
#
#
# Epoch 10, Step 6: 0.143, Most Similar Words: ['individual' 'least' 'less' 'one' 'to'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.58802587 0.5900106  0.5900512  0.6220069  0.548347  ]
#
#
# Epoch 10, Step 7: 0.157, Most Similar Words: ['people' 'one' 'even' 'the' 'less'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.64638156 0.6672129  0.60329884 0.6391839  0.6030519 ]
#
#
# Epoch 10, Step 8: 0.214, Most Similar Words: ['one' 'the' 'of' 'two-way' 'people'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5091632  0.4337117  0.45560277 0.45346984 0.5099656 ]
#
#
# Epoch 10, Step 9: 0.197, Most Similar Words: ['one' 'the' 'of' 'people' 'even'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.5886422  0.52063155 0.6027084  0.5807807  0.53329813]
#
#
# Epoch 10, Step 10: 0.422, Most Similar Words: ['one' 'amount' 'of' 'the' 'less'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.28818065 0.4940431  0.3115543  0.26552042 0.40942967]
#
#
# Epoch 10, Step 11: 0.257, Most Similar Words: ['amount' 'less' 'one' 'increase' 'of'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.45800853 0.48286465 0.4426564  0.41786522 0.37657344]
#
#
# Epoch 10, Step 12: 0.181, Most Similar Words: ['higher' 'less' 'amount' 'increase' 'one'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5127548  0.55829084 0.5804376  0.5102483  0.619037  ]
#
#
# Epoch 10, Step 13: 0.206, Most Similar Words: ['amount' 'increase' 'less' 'higher' 'least'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.45847318 0.49201587 0.51494133 0.4898722  0.5262757 ]
#
#
# Epoch 10, Step 14: 0.302, Most Similar Words: ['amount' 'increase' 'less' 'rate' 'higher'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.4099828  0.45998266 0.4885694  0.27751917 0.4322556 ]
#
#
# Epoch 10, Step 15: 0.244, Most Similar Words: ['less' 'amount' 'amounts' 'increase' 'least'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.6537447 0.7412358 0.6273236 0.6628794 0.5662895]
#
#
# Epoch 10 Average MAE: 0.20634475350379944
# On Epoch 11
# Epoch 11, Step 0: 0.244, Most Similar Words: ['thousand' 'amount' 'amounts' 'total' 'hundred'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.33999166 0.46256763 0.36132005 0.34305438 0.342453  ]
#
#
# Epoch 11, Step 1: 0.213, Most Similar Words: ['amount' 'individual' 'less' 'depending' 'basis'], Target Word: proportion of blacks by town
# ...
# Cosine Similarity between most similar word and target embedding: [0.5012624  0.45215103 0.5219988  0.5473619  0.54144996]
#
#
# Epoch 12, Step 6: 0.443, Most Similar Words: ['of' 'certain' 'i.e.' 'structure' 'present'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.40897065 0.48479384 0.5083478  0.49938768 0.44488063]
#
#
# Epoch 12, Step 7: 0.178, Most Similar Words: ['amount' 'significant' 'greater' 'of' 'certain'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.7412358  0.57999015 0.5927786  0.605316   0.5635437 ]
#
#
# Epoch 12, Step 8: 0.176, Most Similar Words: ['amount' 'greater' 'less' 'increase' 'significant'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.46256763 0.45149878 0.47804335 0.4631949  0.4500702 ]
#
#
# Epoch 12, Step 9: 0.275, Most Similar Words: ['allow' 'operate' 'distance' 'provide' 'accessible'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.4300942  0.3040418  0.39851278 0.38952178 0.32888502]
#
#
# Epoch 12, Step 10: 0.366, Most Similar Words: ['accessible' 'narrow' 'accessibility' 'positionable' 'connecting'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.36325052 0.39711833 0.36325052 0.3175265  0.34143278]
#
#
# Epoch 12, Step 11: 0.173, Most Similar Words: ['different' 'one' 'particular' 'certain' 'area'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5596503  0.6672129  0.54869246 0.58507645 0.54315567]
#
#
# Epoch 12, Step 12: 0.252, Most Similar Words: ['one' 'amount' 'of' 'proportion' 'less'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5091632  0.5814139  0.45560277 0.5415996  0.58687663]
#
#
# Epoch 12, Step 13: 0.228, Most Similar Words: ['proportion' 'amount' 'less' 'increase' 'higher'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.57299984 0.61261314 0.61605316 0.59535706 0.553463  ]
#
#
# Epoch 12, Step 14: 0.362, Most Similar Words: ['of' 'one' 'people' 'the' 'half'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.3115543  0.28818065 0.23912275 0.26552042 0.23377758]
#
#
# Epoch 12, Step 15: 0.313, Most Similar Words: ['amount' 'greater' 'significant' 'proportion' 'certain'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.45800853 0.38412678 0.33176318 0.41193762 0.3882737 ]
#
#
# Epoch 12 Average MAE: 0.2744682729244232
# On Epoch 13
# Epoch 13, Step 0: 0.239, Most Similar Words: ['greater' 'significant' 'proportion' 'amount' 'certain'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5454364 0.5839019 0.5747702 0.5804376 0.5739165]
#
#
# Epoch 13, Step 1: 0.196, Most Similar Words: ['increase' 'less' 'amount' 'significant' 'greater'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.49201587 0.51494133 0.45847318 0.5322585  0.55019   ]
#
#
# Epoch 13, Step 2: 0.189, Most Similar Words: ['less' 'proportion' 'increase' 'greater' 'people'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.4885694  0.35132357 0.45998266 0.5049025  0.44263944]
#
#
# Epoch 13, Step 3: 0.184, Most Similar Words: ['area' 'places' 'people' 'less' 'one'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.43942335 0.4519659  0.5536449  0.6537447  0.58991003]
#
#
# Epoch 13, Step 4: 0.268, Most Similar Words: ['area' 'outside' 'places' 'buildings' 'areas'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.46810213 0.49117842 0.49162176 0.3252826  0.38865224]
#
#
# Epoch 13, Step 5: 0.257, Most Similar Words: ['area' 'places' 'buildings' 'outside' 'place'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.51691216 0.540331   0.4421464  0.49360245 0.530418  ]
#
#
# Epoch 13, Step 6: 0.249, Most Similar Words: ['city' 'of' 'people' 'one' 'majority'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5062459 0.7064992 0.5916456 0.6220069 0.6238739]
#
#
# Epoch 13, Step 7: 0.266, Most Similar Words: ['of' 'people' 'majority' 'the' 'population'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.7311146  0.64638156 0.56444025 0.6391839  0.5051545 ]
#
#
# Epoch 13, Step 8: 0.196, Most Similar Words: ['amount' 'of' 'the' 'one' 'certain'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5814139  0.45560277 0.4337117  0.5091632  0.43572804]
#
#
# Epoch 13, Step 9: 0.174, Most Similar Words: ['amount' 'greater' 'significant' 'increase' 'less'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.61261314 0.5566164  0.57658744 0.59535706 0.61605316]
#
#
# Epoch 13, Step 10: 0.346, Most Similar Words: ['significant' 'one' 'increase' 'greater' 'less'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.46667823 0.28818065 0.48299962 0.47509477 0.40942967]
#
#
# Epoch 13, Step 11: 0.233, Most Similar Words: ['amount' 'increase' 'less' 'significant' 'reduced'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.45800853 0.41786522 0.48286465 0.33176318 0.38393882]
#
#
# Epoch 13, Step 12: 0.258, Most Similar Words: ['per' 'minimum' 'five' 'cost' 'twenty'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.37434256 0.43293288 0.54575723 0.48901692 0.5237015 ]
#
#
# Epoch 13, Step 13: 0.187, Most Similar Words: ['residential' 'area' 'persons' 'houses' 'land'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.4586416  0.5619183  0.47215086 0.47380483 0.47501582]
#
#
# Epoch 13, Step 14: 0.311, Most Similar Words: ['city' 'people' 'country' 'town' 'area'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.46247697 0.44263944 0.40918884 0.3944169  0.5640645 ]
#
#
# Epoch 13, Step 15: 0.293, Most Similar Words: ['city' 'people' 'area' 'one' 'places'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.44818783 0.5536449  0.43942335 0.58991003 0.4519659 ]
#
#
# Epoch 13 Average MAE: 0.24049559235572815
# On Epoch 14
# Epoch 14, Step 0: 0.330, Most Similar Words: ['majority' 'people' 'population' 'area' 'one'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.43148708 0.5305285  0.41405642 0.46810213 0.60319966]
#
#
# Epoch 14, Step 1: 0.211, Most Similar Words: ['of' 'people' 'less' 'one' 'area'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.65781575 0.6586736  0.56628305 0.5943598  0.51691216]
#
#
# Epoch 14, Step 2: 0.169, Most Similar Words: ['less' 'one' 'amount' 'people' 'least'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5900512 0.6220069 0.5889616 0.5916456 0.5900106]
#
#
# Epoch 14, Step 3: 0.255, Most Similar Words: ['significant' 'greater' 'furnish' 'sufficient' 'requisite'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5675325 0.5728054 0.488592  0.488592  0.488592 ]
#
#
# Epoch 14, Step 4: 0.243, Most Similar Words: ['greater' 'possible' 'areas' 'necessary' 'significant'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.5165517  0.43870202 0.42171952 0.37821442 0.4958859 ]
#
#
# Epoch 14, Step 5: 0.310, Most Similar Words: ['allow' 'provide' 'able' 'necessary' 'possible'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.45274758 0.48431915 0.46287253 0.4787344  0.5232228 ]
#
#
# Epoch 14, Step 6: 0.394, Most Similar Words: ['the' 'of' 'one' 'significant' 'greater'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.26552042 0.3115543  0.28818065 0.46667823 0.47509477]
#
#
# Epoch 14, Step 7: 0.241, Most Similar Words: ['one' 'people' 'of' 'first-rate' 'less'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.4426564  0.46063635 0.37657344 0.42763358 0.48286465]
#
#
# Epoch 14, Step 8: 0.195, Most Similar Words: ['of' 'first-rate' 'people' 'one' 'income'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.6333932  0.4563704  0.5731752  0.619037   0.48659936]
#
#
# Epoch 14, Step 9: 0.210, Most Similar Words: ['first-rate' 'of' 'people' 'income' 'pay'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.49120975 0.45215103 0.51539326 0.43676373 0.48010272]
#
#
# Epoch 14, Step 10: 0.233, Most Similar Words: ['people' 'the' 'of' 'one' 'individual'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.44263944 0.47482315 0.40897065 0.47060627 0.45729297]
#
#
# Epoch 14, Step 11: 0.304, Most Similar Words: ['building' 'five' 'home' 'space' 'several'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.4364439  0.5505442  0.4738552  0.44565865 0.46578088]
#
#
# Epoch 14, Step 12: 0.322, Most Similar Words: ['supplementary' 'additional' 'space' 'individual' 'three-component'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.3732652  0.3732652  0.34106964 0.46836284 0.4830596 ]
#
#
# Epoch 14, Step 13: 0.177, Most Similar Words: ['individual' 'less' 'one' 'people' 'even'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.48410496 0.56628305 0.5943598  0.6586736  0.5795255 ]
#
#
# Epoch 14, Step 14: 0.219, Most Similar Words: ['people' 'one' 'city' 'way' 'places'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5916456 0.6220069 0.5062459 0.552506  0.5296698]
#
#
# Epoch 14, Step 15: 0.282, Most Similar Words: ['way' 'the' 'right' 'town' 'city'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.5689038  0.6391839  0.5120294  0.54322684 0.5679271 ]
#
#
# Epoch 14 Average MAE: 0.25589820742607117
# On Epoch 15
# Epoch 15, Step 0: 0.350, Most Similar Words: ['proprietor' 'appoint' 'owner' 'preside' 'voting'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.2917402  0.21711993 0.2917402  0.21711993 0.3387666 ]
#
#
# Epoch 15, Step 1: 0.205, Most Similar Words: ['large' 'the' 'many' 'of' 'unoccupied'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.5852258  0.52063155 0.5470699  0.6027084  0.49068767]
#
#
# Epoch 15, Step 2: 0.272, Most Similar Words: ['of' 'the' 'one' 'many' 'place'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.3115543  0.26552042 0.28818065 0.29969    0.22210763]
#
#
# Epoch 15, Step 3: 0.309, Most Similar Words: ['greater' 'less' 'significant' 'amount' 'one'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.38412678 0.48286465 0.33176318 0.45800853 0.4426564 ]
#
#
# Epoch 15, Step 4: 0.209, Most Similar Words: ['greater' 'less' 'amount' 'increase' 'significant'], Target Word: proportion of owner occupied units built
# Cosine Similarity between most similar word and target embedding: [0.5454364  0.55829084 0.5804376  0.5102483  0.5839019 ]
#
#
# Epoch 15, Step 5: 0.195, Most Similar Words: ['one' 'amount' 'less' 'of' 'increase'], Target Word: distances to five boston employment centres
# Cosine Similarity between most similar word and target embedding: [0.57652646 0.45847318 0.51494133 0.45215103 0.49201587]
#
#
# Epoch 15, Step 6: 0.232, Most Similar Words: ['one' 'less' 'half' 'people' 'amount'], Target Word: accessibility to radial highways
# Cosine Similarity between most similar word and target embedding: [0.47060627 0.4885694  0.3330487  0.44263944 0.4099828 ]
#
#
# Epoch 15, Step 7: 0.200, Most Similar Words: ['city' 'town' 'half' 'country' 'people'], Target Word: full value property tax rate per thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.44818783 0.37856862 0.5660383  0.50867987 0.5536449 ]
#
#
# Epoch 15, Step 8: 0.328, Most Similar Words: ['north-central' 'city' 'town' 'southwest' 'south'], Target Word: pupil to teacher ratio by town
# Cosine Similarity between most similar word and target embedding: [0.45550704 0.54364246 0.5654223  0.3919121  0.3919121 ]
#
#
# Epoch 15, Step 9: 0.345, Most Similar Words: ['access' 'open' 'front' 'right' 'entrance'], Target Word: proportion of blacks by town
# Cosine Similarity between most similar word and target embedding: [0.35114056 0.31409422 0.36615527 0.46698534 0.31262767]
#
#
# Epoch 15, Step 10: 0.231, Most Similar Words: ['city' 'town' 'country' 'half' 'pay'], Target Word: lower status of the population
# Cosine Similarity between most similar word and target embedding: [0.5062459  0.4393947  0.57463133 0.5339737  0.46278977]
#
#
# Epoch 15, Step 11: 0.395, Most Similar Words: ['exchange' 'salary' 'chargeable' 'per' 'charge'], Target Word: value of owner occupied homes in thousand of dollars
# Cosine Similarity between most similar word and target embedding: [0.44859722 0.4266612  0.4776441  0.44337666 0.4776441 ]
#
#
# Epoch 15, Step 12: 0.328, Most Similar Words: ['quantity' 'minimum' 'units' 'per' 'twenty'], Target Word: per capita crime rate by town
# Cosine Similarity between most similar word and target embedding: [0.43626475 0.5265824  0.3891427  0.6803381  0.4437396 ]
#
#
# Epoch 15, Step 13: 0.178, Most Similar Words: ['less' 'amount' 'greater' 'increase' 'significant'], Target Word: proportion of non retail business acres per town
# Cosine Similarity between most similar word and target embedding: [0.61605316 0.61261314 0.5566164  0.59535706 0.57658744]
#
#
# Epoch 15, Step 14: 0.345, Most Similar Words: ['extended' 'position' 'structure' 'positions' 'separate'], Target Word: nitric oxides concentration
# Cosine Similarity between most similar word and target embedding: [0.21416467 0.24060626 0.44164503 0.25613758 0.27579257]
#
#
# Epoch 15, Step 15: 0.316, Most Similar Words: ['greater' 'certain' 'significant' 'i.e.' 'extent'], Target Word: rooms per dwelling
# Cosine Similarity between most similar word and target embedding: [0.38412678 0.3882737  0.33176318 0.42958167 0.31887603]
#
#
# Epoch 15 Average MAE: 0.2773697078227997

# %% [markdown]
# ## Visualize Results

# %%
import pandas as pd

# %%
df = pd.DataFrame(logs)

# %%
df.head()
# Out:
#    learner_mae                                        meta_mae  \
# 0     0.368305  tf.Tensor(0.26711044, shape=(), dtype=float32)
# 1     0.497631   tf.Tensor(0.7196699, shape=(), dtype=float32)
# 2     0.829611  tf.Tensor(0.45501316, shape=(), dtype=float32)
# 3     0.258881  tf.Tensor(0.71464163, shape=(), dtype=float32)
# 4     0.285520    tf.Tensor(0.440401, shape=(), dtype=float32)
#
#    learner_weight_magnitude learner_bias_magnitude  \
# 0                  0.419895           [0.01306174]
# 1                  0.486765         [-0.010412578]
# 2                  0.310316         [0.0153937545]
# 3                  0.296375        [-0.0026668112]
# 4                  0.502571        [-0.0053749904]
#
#                                        guess_cos_sim
# 0  (tf.Tensor(0.5814139, shape=(), dtype=float32)...
# 1  (tf.Tensor(-0.0634368, shape=(), dtype=float32...
# 2  (tf.Tensor(0.04683231, shape=(), dtype=float32...
# 3  (tf.Tensor(0.10267742, shape=(), dtype=float32...
# 4  (tf.Tensor(0.44555473, shape=(), dtype=float32...

# %%
df["meta_mae_numpy"] = [a.numpy() for a in df["meta_mae"]]
df.drop("meta_mae", axis = 1, inplace = True)
df["learner_bias_magnitude_1"] = [a[0] for a in df["learner_bias_magnitude"]]
df["step"] = df.index
df["guess_cos_sim_np"] = [a.numpy() for a in df["guess_cos_sim"]]
df["guess_cos_sim_max"] = [max(a) for a in df["guess_cos_sim_np"]]
for i in range(df["guess_cos_sim_np"].iloc[0].shape[0]):
  df[f"guess_cos_sim_{i}"] = [a[i] for a in df["guess_cos_sim_np"]]
  
df.head()
# Out:
#    learner_mae  learner_weight_magnitude learner_bias_magnitude  \
# 0     0.368305                  0.419895           [0.01306174]
# 1     0.497631                  0.486765         [-0.010412578]
# 2     0.829611                  0.310316         [0.0153937545]
# 3     0.258881                  0.296375        [-0.0026668112]
# 4     0.285520                  0.502571        [-0.0053749904]
#
#                                        guess_cos_sim  meta_mae_numpy  \
# 0  (tf.Tensor(0.5814139, shape=(), dtype=float32)...        0.267110
# 1  (tf.Tensor(-0.0634368, shape=(), dtype=float32...        0.719670
# 2  (tf.Tensor(0.04683231, shape=(), dtype=float32...        0.455013
# 3  (tf.Tensor(0.10267742, shape=(), dtype=float32...        0.714642
# 4  (tf.Tensor(0.44555473, shape=(), dtype=float32...        0.440401
#
#    learner_bias_magnitude_1  step  \
# 0                  0.013062     0
# 1                 -0.010413     1
# 2                  0.015394     2
# 3                 -0.002667     3
# 4                 -0.005375     4
#
#                                     guess_cos_sim_np  guess_cos_sim_max  \
# 0  [0.5814139, 0.62839484, 0.58687663, 0.5543333,...           0.628395
# 1  [-0.0634368, -0.0634368, -0.0634368, -0.159824...          -0.063437
# 2  [0.04683231, 0.17748646, 0.021530366, 0.092883...           0.177486
# 3  [0.10267742, -0.026501244, 0.10267742, 0.10267...           0.102677
# 4  [0.44555473, 0.26178858, 0.3111525, 0.38944885...           0.445555
#
#    guess_cos_sim_0  guess_cos_sim_1  guess_cos_sim_2  guess_cos_sim_3  \
# 0         0.581414         0.628395         0.586877         0.554333
# 1        -0.063437        -0.063437        -0.063437        -0.159824
# 2         0.046832         0.177486         0.021530         0.092883
# 3         0.102677        -0.026501         0.102677         0.102677
# 4         0.445555         0.261789         0.311152         0.389449
#
#    guess_cos_sim_4
# 0         0.495108
# 1        -0.119359
# 2         0.021530
# 3         0.102677
# 4         0.328510

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sns.lineplot(data = df, x = "step", y = "learner_mae", label = "learner_mae")
for i in range(df["guess_cos_sim_np"].iloc[0].shape[0]):
  sns.lineplot(data = df, x = "step", y = f"guess_cos_sim_{i}", label = f"guess_cos_sim_{i}")
sns.lineplot(data = df, x = "step", y = "meta_mae_numpy", label = "meta_mae_numpy")
plt.legend()
# plt.ylim(0,.75)

# %%
df["learner_bias_magnitude_2"] = np.abs(df["learner_bias_magnitude_1"])
df["guess_cos_sim_sum"] = [sum(a) for a in df["guess_cos_sim_np"]]

# %%
sns.scatterplot(data = df, x = "guess_cos_sim_sum", y = "meta_mae_numpy")

# %%
sns.scatterplot(data = df, x = "guess_cos_sim_max", y = "meta_mae_numpy")

# %%
sns.histplot(data = df, x = "guess_cos_sim_max")

# %% [markdown]
# ## Test Interpreter

# %%
from New_Prediction_Pipeline import *

# %%
full_results_dict = {}
number_of_neurons_in_base_model = 32

# %%
import numpy as np
import json
from new_train_sequence_1 import tf
from new_help_functions import *
with open("housing_params.json", "r") as params_json:
  params = json.load(params_json)

vocab, embed_mat, vocab_to_number = load_embed_and_dictionary(params["VOCAB_PATH"], params["EMBED_PATH"])

dataset_generator = load_dataset_generator(params["DATA_PATH"], dataset_name = "salary")

metrics = {"MeanAbsoluteError": tf.keras.metrics.MeanAbsoluteError()}

for train_test_batch, target_col in dataset_generator:

  batch = train_test_batch
  X_train, X_test, y_train, y_test = train_test_batch
  if y_train.name in full_results_dict.keys():
    break
  print(y_train.name)
  base_model = tf.keras.models.Sequential([
                                         tf.keras.layers.Dense(number_of_neurons_in_base_model, activation = "relu"),
                                         tf.keras.layers.Dense(1, activation = "linear")
  ])

  base_model.compile(
      loss = "mse",
      optimizer = "adam",
      metrics = ["mae"]
  )
  feature_embeds = np.array([average_embed(w, embed_mat, vocab_to_number) for w in batch[0].columns]).reshape(1, batch[0].shape[1], -1)
  interp_callback_training = Train_Pipeline(base_model, part_a_interpreter, algo, -1, feature_embeds, number_of_neurons_in_base_model, tf.keras.losses.MeanSquaredError(), tf.keras.optimizers.Adam(), target_col, metrics)
  interp_callback_training.fit(X_train, y_train, params["BATCH_SIZE"], 1, 16)
  final_preds = []
  for i in interp_callback_training.interpreter_callback.interpreter_output_words:
    final_preds.append(i[-1])
  full_results_dict[y_train.name] = final_preds
# Out:
# per capita crime rate by town
# On Epoch 0
# 100%|██████████| 16/16 [00:00<00:00, 90.61it/s]
# MeanAbsoluteError: 0.05
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.12
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 108.62it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 101.77it/s]
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 109.34it/s]
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 106.95it/s]
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 117.61it/s]
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 109.76it/s]
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 103.40it/s]
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 99.05it/s]
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.06
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 107.32it/s]
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# MeanAbsoluteError: 0.06
# proportion of non retail business acres per town
# On Epoch 0
# 100%|██████████| 16/16 [00:00<00:00, 94.81it/s]
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.07
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.08
# MeanAbsoluteError: 0.09
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 91.25it/s]
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.09
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 105.48it/s]
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.10
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 102.58it/s]
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 95.07it/s]
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 97.33it/s]
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 103.79it/s]
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 105.42it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 104.20it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.11
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 106.32it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# nitric oxides concentration
# On Epoch 0
#  44%|████▍     | 7/16 [00:00<00:00, 64.39it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# 100%|██████████| 16/16 [00:00<00:00, 74.21it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 103.61it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 107.42it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 94.55it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 104.80it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 108.56it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 100.48it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 105.61it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 95.59it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 105.33it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# rooms per dwelling
# On Epoch 0
#  44%|████▍     | 7/16 [00:00<00:00, 65.91it/s]
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.12
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# 100%|██████████| 16/16 [00:00<00:00, 81.20it/s]
# MeanAbsoluteError: 0.13
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 105.59it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 109.55it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 111.63it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 99.56it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 95.03it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 6
#  25%|██▌       | 4/16 [00:00<00:00, 31.60it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
#  88%|████████▊ | 14/16 [00:00<00:00, 39.03it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# 100%|██████████| 16/16 [00:00<00:00, 36.45it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 7
#  31%|███▏      | 5/16 [00:00<00:00, 49.45it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# 100%|██████████| 16/16 [00:00<00:00, 41.48it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 109.24it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 110.85it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# proportion of owner occupied units built
# On Epoch 0
#  38%|███▊      | 6/16 [00:00<00:00, 58.94it/s]
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.13
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
#  75%|███████▌  | 12/16 [00:00<00:00, 58.53it/s]
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# 100%|██████████| 16/16 [00:00<00:00, 60.64it/s]
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 92.82it/s]
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# On Epoch 2
#  31%|███▏      | 5/16 [00:00<00:00, 42.86it/s]
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.14
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# 100%|██████████| 16/16 [00:00<00:00, 42.54it/s]
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 98.10it/s]
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 99.87it/s]
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 103.07it/s]
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 99.12it/s]
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.15
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 103.14it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 105.97it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 94.16it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# distances to five boston employment centres
# On Epoch 0
#  38%|███▊      | 6/16 [00:00<00:00, 56.83it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# 100%|██████████| 16/16 [00:00<00:00, 71.80it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 95.04it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 103.59it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 98.06it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 100.49it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 108.50it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 91.72it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 98.70it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 105.39it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 101.55it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# accessibility to radial highways
# On Epoch 0
#  50%|█████     | 8/16 [00:00<00:00, 76.79it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# 100%|██████████| 16/16 [00:00<00:00, 77.71it/s]
# MeanAbsoluteError: 0.16
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 112.34it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 104.10it/s]
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.16
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 107.37it/s]
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 109.68it/s]
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.17
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 98.30it/s]
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 103.50it/s]
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 88.00it/s]
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 105.61it/s]
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 94.62it/s]
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# full value property tax rate per thousand of dollars
# On Epoch 0
#  56%|█████▋    | 9/16 [00:00<00:00, 89.07it/s]
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.18
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# 100%|██████████| 16/16 [00:00<00:00, 87.78it/s]
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 103.83it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 100.33it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 100.60it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 104.62it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 99.02it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 103.79it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 109.52it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 104.86it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 94.89it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# pupil to teacher ratio by town
# On Epoch 0
#  31%|███▏      | 5/16 [00:00<00:00, 44.45it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# 100%|██████████| 16/16 [00:00<00:00, 44.12it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 1
#  44%|████▍     | 7/16 [00:00<00:00, 69.71it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# 100%|██████████| 16/16 [00:00<00:00, 75.13it/s]
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 101.49it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 108.42it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 96.47it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 97.52it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 95.95it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 104.95it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 103.69it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 89.11it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# proportion of blacks by town
# On Epoch 0
#  50%|█████     | 8/16 [00:00<00:00, 74.83it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# 100%|██████████| 16/16 [00:00<00:00, 73.77it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 95.18it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 103.64it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 104.61it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 95.04it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 94.90it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 101.77it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 100.62it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 108.64it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 94.72it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# lower status of the population
# On Epoch 0
#  50%|█████     | 8/16 [00:00<00:00, 74.44it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# 100%|██████████| 16/16 [00:00<00:00, 84.41it/s]
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 94.22it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 97.99it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 98.51it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 96.34it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 101.40it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 101.32it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 100.35it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 99.57it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 9
# 100%|██████████| 16/16 [00:00<00:00, 93.27it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# value of owner occupied homes in thousand of dollars
# On Epoch 0
#  44%|████▍     | 7/16 [00:00<00:00, 65.47it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# 100%|██████████| 16/16 [00:00<00:00, 74.52it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# On Epoch 1
# 100%|██████████| 16/16 [00:00<00:00, 110.98it/s]
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.19
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 2
# 100%|██████████| 16/16 [00:00<00:00, 102.03it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 3
# 100%|██████████| 16/16 [00:00<00:00, 99.45it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 4
# 100%|██████████| 16/16 [00:00<00:00, 95.55it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 5
# 100%|██████████| 16/16 [00:00<00:00, 105.24it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 6
# 100%|██████████| 16/16 [00:00<00:00, 105.33it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 7
# 100%|██████████| 16/16 [00:00<00:00, 95.29it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 8
# 100%|██████████| 16/16 [00:00<00:00, 99.40it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# On Epoch 9
#  25%|██▌       | 4/16 [00:00<00:00, 29.74it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
#  81%|████████▏ | 13/16 [00:00<00:00, 37.71it/s]
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# MeanAbsoluteError: 0.20
# 100%|██████████| 16/16 [00:00<00:00, 35.12it/s]
# MeanAbsoluteError: 0.20

# %%
full_results_dict
# Out:
# {'accessibility to radial highways': [array(['amount', 'increase', 'greater', 'less', 'higher'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'amount', 'less', 'greater', 'higher'], dtype='<U22'),
#   array(['amount', 'increase', 'greater', 'less', 'higher'], dtype='<U22'),
#   array(['amount', 'greater', 'less', 'increase', 'higher'], dtype='<U22'),
#   array(['amount', 'increase', 'greater', 'less', 'higher'], dtype='<U22'),
#   array(['amount', 'greater', 'increase', 'higher', 'less'], dtype='<U22'),
#   array(['increase', 'amount', 'greater', 'less', 'higher'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'greater', 'higher'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'greater', 'higher'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'greater', 'higher'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'greater', 'less', 'higher'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'greater', 'higher'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'greater', 'higher'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'higher', 'greater'], dtype='<U22'),
#   array(['amount', 'greater', 'increase', 'higher', 'less'], dtype='<U22'),
#   array(['increase', 'amount', 'greater', 'less', 'higher'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'greater', 'higher'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'greater', 'increase', 'less', 'higher'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'amount', 'less', 'greater', 'higher'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'amount', 'less', 'greater', 'higher'], dtype='<U22')],
#  'distances to five boston employment centres': [array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'less', 'amount', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'less', 'increase', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'greater', 'reduced', 'less'], dtype='<U22'),
#   array(['increase', 'less', 'amount', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'less', 'amount', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'less', 'amount', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'less', 'increase', 'reduced', 'greater'], dtype='<U22'),
#   array(['amount', 'increase', 'greater', 'reduced', 'less'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'greater', 'reduced', 'less'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'greater', 'reduced', 'less'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'greater', 'reduced', 'less'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'less', 'amount', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22')],
#  'full value property tax rate per thousand of dollars': [array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'greater', 'significant', 'increase', 'amount'],
#         dtype='<U22')],
#  'lower status of the population': [array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['lease', 'unit', 'units', 'purchase', 'acres'], dtype='<U22'),
#   array(['purchase', 'unit', 'lease', 'units', 'acres'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['lease', 'purchase', 'units', 'acres', 'unit'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'unit', 'lease', 'purchase', 'acres'], dtype='<U22'),
#   array(['units', 'purchase', 'unit', 'lease', 'acres'], dtype='<U22'),
#   array(['units', 'purchase', 'unit', 'lease', 'acres'], dtype='<U22'),
#   array(['units', 'unit', 'purchase', 'lease', 'acres'], dtype='<U22'),
#   array(['units', 'unit', 'purchase', 'lease', 'acres'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'purchase', 'unit', 'lease', 'acres'], dtype='<U22'),
#   array(['units', 'unit', 'purchase', 'lease', 'acres'], dtype='<U22'),
#   array(['units', 'unit', 'purchase', 'lease', 'acres'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['unit', 'purchase', 'lease', 'units', 'acres'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['purchase', 'unit', 'units', 'acres', 'lease'], dtype='<U22'),
#   array(['units', 'unit', 'purchase', 'lease', 'acres'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['lease', 'purchase', 'units', 'acres', 'unit'], dtype='<U22'),
#   array(['unit', 'purchase', 'lease', 'units', 'acres'], dtype='<U22'),
#   array(['unit', 'purchase', 'lease', 'units', 'acres'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'unit', 'purchase', 'lease', 'acres'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22')],
#  'nitric oxides concentration': [array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['amount', 'one', 'less', 'pay', 'increase'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22')],
#  'per capita crime rate by town': [array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'dollars', 'unit', 'per', 'invests'], dtype='<U22'),
#   array(['units', 'dollars', 'per', 'unit', 'invests'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'dollars', 'per', 'unit', 'invests'], dtype='<U22'),
#   array(['per', 'units', 'unit', 'dollars', 'invests'], dtype='<U22'),
#   array(['units', 'per', 'dollars', 'unit', 'invests'], dtype='<U22'),
#   array(['invests', 'units', 'per', 'dollars', 'unit'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'dollars', 'per', 'unit', 'invests'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'dollars', 'unit', 'per', 'invests'], dtype='<U22'),
#   array(['units', 'dollars', 'per', 'unit', 'invests'], dtype='<U22'),
#   array(['units', 'per', 'dollars', 'unit', 'invests'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'dollars', 'unit', 'per', 'invests'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'dollars', 'per', 'unit', 'invests'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['invests', 'dollars', 'per', 'units', 'unit'], dtype='<U22'),
#   array(['units', 'dollars', 'per', 'unit', 'invests'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'dollars', 'unit', 'per', 'invests'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['units', 'dollars', 'unit', 'per', 'invests'], dtype='<U22'),
#   array(['units', 'dollars', 'per', 'unit', 'invests'], dtype='<U22')],
#  'proportion of blacks by town': [array(['amount', 'amounts', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['amount', 'amounts', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['amounts', 'amount', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'less', 'amount', 'amounts', 'reduced'], dtype='<U22'),
#   array(['less', 'amount', 'amounts', 'increase', 'reduced'], dtype='<U22'),
#   array(['less', 'amount', 'amounts', 'increase', 'reduced'], dtype='<U22'),
#   array(['amount', 'amounts', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['amounts', 'amount', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['amounts', 'amount', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['amounts', 'amount', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['increase', 'less', 'amount', 'amounts', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'amounts', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'amounts', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'amounts', 'amount', 'increase', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amounts', 'amount', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['less', 'amount', 'amounts', 'increase', 'reduced'], dtype='<U22'),
#   array(['amounts', 'amount', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['less', 'amount', 'amounts', 'increase', 'reduced'], dtype='<U22'),
#   array(['amount', 'amounts', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['amounts', 'less', 'amount', 'increase', 'reduced'], dtype='<U22'),
#   array(['amount', 'amounts', 'less', 'increase', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22')],
#  'proportion of non retail business acres per town': [array(['loft', 'lease', 'bath', 'proprietor', 'owner'], dtype='<U22'),
#   array(['lease', 'owner', 'loft', 'bath', 'proprietor'], dtype='<U22'),
#   array(['loft', 'lease', 'bath', 'owner', 'proprietor'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['lease', 'bath', 'loft', 'owner', 'proprietor'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['bath', 'lease', 'owner', 'loft', 'proprietor'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['loft', 'lease', 'bath', 'proprietor', 'owner'], dtype='<U22'),
#   array(['lease', 'loft', 'bath', 'proprietor', 'owner'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['bath', 'lease', 'loft', 'proprietor', 'owner'], dtype='<U22'),
#   array(['loft', 'bath', 'proprietor', 'lease', 'owner'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['lease', 'loft', 'proprietor', 'bath', 'owner'], dtype='<U22'),
#   array(['loft', 'lease', 'bath', 'proprietor', 'owner'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['lease', 'loft', 'bath', 'proprietor', 'owner'], dtype='<U22'),
#   array(['lease', 'bath', 'proprietor', 'loft', 'owner'], dtype='<U22'),
#   array(['loft', 'bath', 'lease', 'owner', 'proprietor'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['loft', 'lease', 'proprietor', 'bath', 'owner'], dtype='<U22'),
#   array(['bath', 'loft', 'proprietor', 'lease', 'owner'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['bath', 'loft', 'proprietor', 'lease', 'owner'], dtype='<U22')],
#  'proportion of owner occupied units built': [array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'amounts', 'reduced'], dtype='<U22'),
#   array(['amount', 'increase', 'amounts', 'less', 'reduced'], dtype='<U22'),
#   array(['less', 'amounts', 'reduced', 'increase', 'amount'], dtype='<U22'),
#   array(['amount', 'reduced', 'less', 'increase', 'amounts'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'amounts', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'amount', 'less', 'reduced', 'amounts'], dtype='<U22'),
#   array(['less', 'amounts', 'increase', 'amount', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'amounts', 'reduced'], dtype='<U22'),
#   array(['less', 'increase', 'amounts', 'reduced', 'amount'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'increase', 'amounts', 'reduced', 'amount'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'amount', 'less', 'amounts', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'amount', 'amounts', 'less', 'reduced'], dtype='<U22')],
#  'pupil to teacher ratio by town': [array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'reduced', 'amount', 'less', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'amount', 'increase', 'reduced', 'greater'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'amount', 'increase', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'amount', 'increase', 'reduced', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'reduced', 'amount', 'less', 'greater'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'reduced', 'greater'], dtype='<U22')],
#  'rooms per dwelling': [array(['amount', 'less', 'increase', 'amounts', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['reduced', 'amounts', 'less', 'increase', 'amount'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'less', 'increase', 'amounts', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['increase', 'amount', 'less', 'amounts', 'reduced'], dtype='<U22'),
#   array(['amount', 'increase', 'amounts', 'less', 'reduced'], dtype='<U22'),
#   array(['amount', 'less', 'increase', 'amounts', 'reduced'], dtype='<U22'),
#   array(['amount', 'less', 'increase', 'amounts', 'reduced'], dtype='<U22'),
#   array(['less', 'increase', 'amounts', 'amount', 'reduced'], dtype='<U22'),
#   array(['amount', 'less', 'increase', 'amounts', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'amounts', 'less', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'amount', 'increase', 'amounts', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['less', 'amount', 'increase', 'amounts', 'reduced'], dtype='<U22'),
#   array(['amount', 'increase', 'amounts', 'less', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'amounts', 'less', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'increase', 'less', 'amounts', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['amount', 'less', 'increase', 'amounts', 'reduced'], dtype='<U22'),
#   array(['amount', 'increase', 'amounts', 'less', 'reduced'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22')],
#  'value of owner occupied homes in thousand of dollars': [array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['bath', 'pellet', 'fireplace', 'suite', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['bath', 'fireplace', 'pellet', 'suite', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['fireplace', 'bath', 'pellet', 'suite', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['buys', 'bath', 'fireplace', 'suite', 'pellet'], dtype='<U22'),
#   array(['fireplace', 'bath', 'pellet', 'suite', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['pellet', 'bath', 'fireplace', 'suite', 'buys'], dtype='<U22'),
#   array(['bath', 'pellet', 'suite', 'fireplace', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['fireplace', 'pellet', 'bath', 'suite', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['fireplace', 'bath', 'pellet', 'suite', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['bath', 'fireplace', 'pellet', 'suite', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22'),
#   array(['pellet', 'bath', 'fireplace', 'suite', 'buys'], dtype='<U22'),
#   array(['bath', 'pellet', 'suite', 'fireplace', 'buys'], dtype='<U22'),
#   array(['bath', 'suite', 'fireplace', 'pellet', 'buys'], dtype='<U22'),
#   array(['fireplace', 'suite', 'pellet', 'bath', 'buys'], dtype='<U22'),
#   array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#         dtype='<U22')]}

# %%
full_results_dict['value of owner occupied homes in thousand of dollars']
# Out:
# [array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['bath', 'pellet', 'fireplace', 'suite', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['bath', 'fireplace', 'pellet', 'suite', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['fireplace', 'bath', 'pellet', 'suite', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['buys', 'bath', 'fireplace', 'suite', 'pellet'], dtype='<U22'),
#  array(['fireplace', 'bath', 'pellet', 'suite', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['pellet', 'bath', 'fireplace', 'suite', 'buys'], dtype='<U22'),
#  array(['bath', 'pellet', 'suite', 'fireplace', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['fireplace', 'pellet', 'bath', 'suite', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['fireplace', 'bath', 'pellet', 'suite', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['bath', 'fireplace', 'pellet', 'suite', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22'),
#  array(['pellet', 'bath', 'fireplace', 'suite', 'buys'], dtype='<U22'),
#  array(['bath', 'pellet', 'suite', 'fireplace', 'buys'], dtype='<U22'),
#  array(['bath', 'suite', 'fireplace', 'pellet', 'buys'], dtype='<U22'),
#  array(['fireplace', 'suite', 'pellet', 'bath', 'buys'], dtype='<U22'),
#  array(['banner', 'baltimore', 'coral', 'florida', 'star-spangled'],
#        dtype='<U22')]

# %%
for k in full_results_dict.keys():
  full_results_dict[k] = [i.tolist() for i in full_results_dict[k]]

# %%
import json

with open("housing_interpretation_results_static.json", "w") as results_json:
  json.dump(full_results_dict, results_json)
